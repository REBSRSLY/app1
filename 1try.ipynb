# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.59.2-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from streamlit) (6.0.0)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.51-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging>=20 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from streamlit) (12.0.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf<8,>=3.20 (from streamlit)
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting pyarrow<25,>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting requests<3,>=2.27 (from streamlit)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from streamlit) (4.15.0)
# Collecting starlette>=0.40.0 (from streamlit)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn>=0.30.0 (from streamlit)
#   Downloading uvicorn-0.51.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting httptools>=0.6.3 (from streamlit)
#   Downloading httptools-0.8.0-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting anyio>=4.0.0 (from streamlit)
#   Downloading anyio-4.14.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting python-multipart>=0.0.10 (from streamlit)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Collecting websockets>=12.0.0 (from streamlit)
#   Downloading websockets-16.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.1)
# Requirement already satisfied: colorama in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.27->streamlit)
#   Downloading charset_normalizer-3.4.9-cp311-cp311-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Collecting urllib3<3,>=1.26 (from requests<3,>=2.27->streamlit)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Collecting h11>=0.8 (from uvicorn>=0.30.0->streamlit)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Downloading streamlit-1.59.2-py3-none-any.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    --------------- ------------------------ 3.9/10.3 MB 19.5 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.3 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 18.4 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading gitpython-3.1.51-py3-none-any.whl (215 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl (27.3 MB)
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    ------ --------------------------------- 4.2/27.3 MB 21.0 MB/s eta 0:00:02
#    ------------ --------------------------- 8.4/27.3 MB 20.0 MB/s eta 0:00:01
#    ------------------ --------------------- 12.6/27.3 MB 20.2 MB/s eta 0:00:01
#    ------------------------ --------------- 16.8/27.3 MB 19.9 MB/s eta 0:00:01
#    ------------------------------- -------- 21.2/27.3 MB 20.0 MB/s eta 0:00:01
#    ------------------------------------- -- 25.4/27.3 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 18.8 MB/s  0:00:01
# Downloading pydeck-0.9.3-py2.py3-none-any.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    -------------- ------------------------- 4.2/11.4 MB 21.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.4 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 18.3 MB/s  0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.9-cp311-cp311-win_amd64.whl (161 kB)
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading anyio-4.14.2-py3-none-any.whl (125 kB)
# Downloading httptools-0.8.0-cp311-cp311-win_amd64.whl (90 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
# Downloading uvicorn-0.51.0-py3-none-any.whl (73 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading websockets-16.1-cp311-cp311-win_amd64.whl (180 kB)
# Installing collected packages: websockets, watchdog, urllib3, toml, tenacity, smmap, python-multipart, pyarrow, protobuf, itsdangerous, httptools, h11, click, charset_normalizer, cachetools, blinker, anyio, uvicorn, starlette, requests, pydeck, gitdb, gitpython, streamlit
#
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    ----------------------------------------  0/24 [websockets]
#    - --------------------------------------  1/24 [watchdog]
#    - --------------------------------------  1/24 [watchdog]
#    - --------------------------------------  1/24 [watchdog]
#    - --------------------------------------  1/24 [watchdog]
#    - --------------------------------------  1/24 [watchdog]
#    - --------------------------------------  1/24 [watchdog]
#    --- ------------------------------------  2/24 [urllib3]
#    --- ------------------------------------  2/24 [urllib3]
#    --- ------------------------------------  2/24 [urllib3]
#    --- ------------------------------------  2/24 [urllib3]
#    --- ------------------------------------  2/24 [urllib3]
#    --- ------------------------------------  2/24 [urllib3]
#    --- ------------------------------------  2/24 [urllib3]
#    ----- ----------------------------------  3/24 [toml]
#    ------ ---------------------------------  4/24 [tenacity]
#    ------ ---------------------------------  4/24 [tenacity]
#    ------ ---------------------------------  4/24 [tenacity]
#    -------- -------------------------------  5/24 [smmap]
#    -------- -------------------------------  5/24 [smmap]
#    ---------- -----------------------------  6/24 [python-multipart]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    ------------- --------------------------  8/24 [protobuf]
#    --------------- ------------------------  9/24 [itsdangerous]
#    --------------- ------------------------  9/24 [itsdangerous]
#    ---------------- ----------------------- 10/24 [httptools]
#    ------------------ --------------------- 11/24 [h11]
#    ------------------ --------------------- 11/24 [h11]
#    ------------------ --------------------- 11/24 [h11]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    -------------------- ------------------- 12/24 [click]
#    --------------------- ------------------ 13/24 [charset_normalizer]
#    --------------------- ------------------ 13/24 [charset_normalizer]
#    --------------------- ------------------ 13/24 [charset_normalizer]
#    --------------------- ------------------ 13/24 [charset_normalizer]
#    ----------------------- ---------------- 14/24 [cachetools]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ---------------------------- ----------- 17/24 [uvicorn]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------ --------- 18/24 [starlette]
#    ------------------------------- -------- 19/24 [requests]
#    ------------------------------- -------- 19/24 [requests]
#    ------------------------------- -------- 19/24 [requests]
#    ------------------------------- -------- 19/24 [requests]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    --------------------------------- ------ 20/24 [pydeck]
#    ----------------------------------- ---- 21/24 [gitdb]
#    ----------------------------------- ---- 21/24 [gitdb]
#    ----------------------------------- ---- 21/24 [gitdb]
#    ----------------------------------- ---- 21/24 [gitdb]
#    ----------------------------------- ---- 21/24 [gitdb]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    ------------------------------------ --- 22/24 [gitpython]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    ---------------------------------------- 24/24 [streamlit]
#
# Successfully installed anyio-4.14.2 blinker-1.9.0 cachetools-7.1.4 charset_normalizer-3.4.9 click-8.4.2 gitdb-4.0.12 gitpython-3.1.51 h11-0.16.0 httptools-0.8.0 itsdangerous-2.2.0 protobuf-7.35.1 pyarrow-24.0.0 pydeck-0.9.3 python-multipart-0.0.32 requests-2.34.2 smmap-5.0.3 starlette-1.3.1 streamlit-1.59.2 tenacity-9.1.4 toml-0.10.2 urllib3-2.7.0 uvicorn-0.51.0 watchdog-6.0.0 websockets-16.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\rebec\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import streamlit as st

# Configurazione della pagina Streamlit
st.set_page_config(
    page_title="Vero Volley Milano - Staff Tecnico",
    page_icon="🏐",
    layout="wide",
    initial_sidebar_state="expanded"
)

# ---------------------------------------------------------------------------
# CSS Personalizzato per replicare lo stile pulito del mockup React
# ---------------------------------------------------------------------------
st.markdown("""
    <style>
        /* Variabili e stili generali */
        :root {
            --accent: #c0392b;
            --accent-bg: #fbeceb;
            --muted: #8a8a8a;
            --line: #e6e6e6;
        }
        
        /* Stile sidebar */
        .css-1d391kg { padding-top: 2rem; }
        .brand-title {
            font-size: 1.1rem;
            font-weight: 700;
            color: #1a1a1a;
            margin-bottom: 0px;
        }
        .brand-subtitle {
            font-size: 0.8rem;
            color: var(--muted);
            margin-bottom: 1.5rem;
        }
        
        /* Box Bozze di lavoro */
        .draft-block {
            border: 1px dashed #c6c6c6;
            border-radius: 10px;
            padding: 16px;
            background-color: #fcfcfc;
            margin-bottom: 15px;
        }
        .draft-label {
            font-size: 11px;
            text-transform: uppercase;
            letter-spacing: 0.08em;
            color: #8a8a8a;
            font-weight: bold;
            margin-bottom: 10px;
        }
        .ph-line {
            color: #555555;
            font-size: 13.5px;
            margin-bottom: 8px;
        }
        .ph-line:last-child { margin-bottom: 0; }

        /* Card di Allerta (TQR) */
        .alert-card {
            background-color: #fff6ea;
            border: 1px solid #f0dcb4;
            border-radius: 8px;
            padding: 12px;
            font-size: 13px;
            color: #1a1a1a;
            margin-bottom: 15px;
            display: flex;
            align-items: center;
            gap: 10px;
        }

        /* Badge di Capitano */
        .cap-tag {
            display: inline-block;
            margin-left: 8px;
            font-size: 10px;
            font-style: normal;
            text-transform: uppercase;
            color: #c0392b;
            border: 1px solid #e6bdb8;
            border-radius: 4px;
            padding: 1px 5px;
            font-weight: bold;
        }

        /* Chips per le date delle partite */
        .chip-container {
            display: flex;
            flex-wrap: wrap;
            gap: 8px;
            margin-top: 10px;
        }
        .date-chip {
            border: 1px solid #e6e6e6;
            border-radius: 7px;
            padding: 4px 10px;
            font-size: 12.5px;
            font-family: monospace;
            color: #444;
            background-color: #ffffff;
        }
    </style>
""", unsafe_allow_html=True)

# ---------------------------------------------------------------------------
# Dati reali di riferimento (Vero Volley Milano, A1 Femminile 23/24)
# ---------------------------------------------------------------------------

titolari = [
    {"pos": "P1", "role": "Palleggio", "name": "Orro", "code": "TS3H", "tag": "Capitano"},
    {"pos": "P2", "role": "Opposto", "name": "Egonu", "code": "3GS4"},
    {"pos": "P3", "role": "Centro", "name": "Folie", "code": "8EZC", "alt": "Heyrman (Z4SY)"},
    {"pos": "P4", "role": "Banda", "name": "Sylla", "code": "09RI"},
    {"pos": "P5", "role": "Banda", "name": "Cazaute", "code": "62DH", "alt": "Daalderop (II9W)"},
    {"pos": "P6", "role": "Centro", "name": "Rettke", "code": "XPN2"},
    {"pos": "L", "role": "Libero", "name": "Castillo", "code": "W0GU"},
]

panchina = [
    {"role": "Opposto", "name": "Malual", "code": "P4T5"},
    {"role": "Centro", "name": "Candi", "code": "NEMC"},
    {"role": "Palleggio", "name": "Prandi", "code": "LC8Z"},
    {"role": "Banda", "name": "Bajema", "code": "1L4C"},
    {"role": "Libero", "name": "Parrocchiale", "code": "M9TM"},
    {"role": "Libero", "name": "Pusic", "code": "BWR1"},
]

partite = [
    "24-05-05", "24-04-10", "24-04-06", "24-03-31", "24-03-27", "24-03-24",
    "24-03-19", "24-03-16", "24-03-12", "24-03-09", "...", "23-10-14", "23-10-08"
]

# ---------------------------------------------------------------------------
# Sidebar & Navigazione
# ---------------------------------------------------------------------------

with st.sidebar:
    st.markdown('<div class="brand-title">Vero Volley Milano</div>', unsafe_allow_html=True)
    st.markdown('<div class="brand-subtitle">Staff tecnico · A1 Femminile</div>', unsafe_allow_html=True)
    
    # Menu di navigazione nativo di Streamlit
    menu = st.radio(
        "Menu Navigazione",
        ["Home", "Atlete", "Partite", "Carico & Wellness", "Confronti", "Formazioni", "Inserimento dati"],
        label_visibility="collapsed"
    )

# Funzione Shell di Sezione
def section_header(title, purpose):
    st.title(title)
    st.caption(purpose)
    st.write("---")

# ---------------------------------------------------------------------------
# Rendering Sezioni
# ---------------------------------------------------------------------------

# --- HOME ---
if menu == "Home":
    section_header("Home", "Colpo d'occhio giornaliero per lo staff: cosa richiede attenzione oggi, in bozza — da definire insieme.")
    
    # Allerta recupero
    st.markdown("""
        <div class="alert-card">
            ⚠️ <b>Recupero basso</b> — Egonu (TQR 11.2), Orro (12.4), Bajema (12.3) sotto soglia questa settimana
        </div>
    """, unsafe_allow_html=True)
    
    # Bozza di lavoro
    st.markdown("""
        <div class="draft-block">
            <div class="draft-label">Bozza di lavoro</div>
            <div class="ph-line">📅 Prossimo impegno (partita/allenamento) — nessuna fonte dati calendario ancora collegata</div>
            <div class="ph-line">⚡ Accesso rapido: Atlete · Partite · Inserimento dati</div>
        </div>
    """, unsafe_allow_html=True)

# --- ATLETE ---
elif menu == "Atlete":
    section_header("Atlete", "Rosa completa. Ogni riga apre la scheda individuale con wellness + rendimento incrociati.")
    
    search_query = st.text_input("🔍 Cerca atleta...", placeholder="Inserisci il nome...")
    
    # Funzione helper per filtrare e visualizzare le atlete
    def render_atleta_row(p, is_titolare=True):
        pos_str = f"**{p['pos']}**" if is_titolare else "—"
        tag_html = f'<span class="cap-tag">{p["tag"]}</span>' if "tag" in p else ""
        alt_str = f" *(alterna con {p['alt']})*" if "alt" in p else ""
        
        col1, col2, col3, col4 = st.columns([1, 4, 3, 2])
        with col1:
            st.markdown(pos_str)
        with col2:
            st.markdown(f"**{p['name']}** {tag_html}", unsafe_allow_html=True)
        with col3:
            st.write(p['role'])
        with col4:
            st.code(p['code'])
        
        if alt_str:
            st.caption(alt_str)
        st.write("---")

    st.subheader("Titolari")
    st.write("---")
    for p in titolari:
        if not search_query or search_query.lower() in p['name'].lower():
            render_atleta_row(p, is_titolare=True)
            
    st.subheader("Panchina")
    st.write("---")
    for p in panchina:
        if not search_query or search_query.lower() in p['name'].lower():
            render_atleta_row(p, is_titolare=False)

# --- PARTITE ---
elif menu == "Partite":
    section_header("Partite", "Elenco partite stagione (45 rilevate). Ogni partita apre lo scouting per fondamentale.")
    
    st.text_input("🔍 Filtra per data...", placeholder="Es. 24-03")
    
    # Rendering dei chip delle date delle partite in HTML
    chips_html = "".join([f'<span class="date-chip">{d}</span>' for d in partite])
    st.markdown(f'<div class="chip-container">{chips_html}</div>', unsafe_allow_html=True)
    
    st.write("")
    st.info("Ogni scheda partita: statistiche per fondamentale (come nel foglio TOTALE) + possibilità di filtrare per singola atleta.")

# --- CARICO & WELLNESS ---
elif menu == "Carico & Wellness":
    section_header("Carico & Wellness", "Monitoraggio giornaliero: questionario wellness (Fatica, Sonno, Doms, Stress, Mood, TQR), RPE/Training Load, conteggio salti — per squadra o singola atleta.")
    
    st.markdown("""
        <div class="draft-block">
            <div class="draft-label">Bozza di lavoro</div>
            <div class="ph-line">📈 <b>Vista squadra:</b> trend TQR medio nel tempo (già in bozza nel primo mockup)</div>
            <div class="ph-line">👤 <b>Vista atleta:</b> stesso trend filtrato + confronto con carico (RPE × durata) e salti giornalieri</div>
            <div class="ph-line">⚙️ Soglie di allerta configurabili (es. TQR sotto una certa media)</div>
        </div>
    """, unsafe_allow_html=True)

# --- CONFRONTI ---
elif menu == "Confronti":
    section_header("Confronti", "Mettere a confronto due o più atlete, o due periodi della stagione, sulle stesse metriche (wellness o scouting).")
    
    st.markdown("""
        <div class="draft-block">
            <div class="draft-label">Bozza di lavoro</div>
            <div class="ph-line">🎛️ <b>Selettore:</b> 2+ atlete oppure 2 intervalli di date</div>
            <div class="ph-line">📊 <b>Metriche disponibili:</b> qualsiasi fondamentale scouting, TQR, RPE, salti</div>
            <div class="ph-line">💡 <b>Esempio d'uso:</b> Folie vs Heyrman nel periodo di alternanza per infortunio</div>
        </div>
    """, unsafe_allow_html=True)

# --- FORMAZIONI ---
elif menu == "Formazioni":
    section_header("Formazioni", "Sestetto titolare, rotazioni e alternanze per ruolo, con lo stato di recupero di chi è in campo.")
    
    # Rappresentazione del campo da gioco (3x2 per il sestetto attivo)
    st.subheader("Disposizione in Campo (Sestetto)")
    
    campo_titolari = [p for p in titolari if p["pos"] != "L"]
    
    # Divisione in 3 colonne per simulare la griglia del campo da gioco
    cols = st.columns(3)
    for i, p in enumerate(campo_titolari):
        col_index = i % 3
        with cols[col_index]:
            alt_text = f"\n↔ {p['alt']}" if "alt" in p else ""
            st.metric(
                label=f"{p['pos']} - {p['role']}",
                value=p['name'],
                delta=alt_text if alt_text else None,
                delta_color="off"
            )
            
    st.write("---")
    libero = next(p for p in titolari if p["pos"] == "L")
    st.write(f"🛡️ **Libero:** {libero['name']} (`{libero['code']}`)")

# --- INSERIMENTO DATI ---
elif menu == "Inserimento dati":
    section_header("Inserimento dati", "Caricamento nuovi dati: wellness/RPE/salti giornalieri per atleta, oppure scouting di una nuova partita.")
    
    st.markdown("""
        <div class="draft-block">
            <div class="draft-label">Bozza di lavoro</div>
            <div class="ph-line">📝 <b>Form wellness giornaliero:</b> seleziona atleta + data → Fatica, Sonno, Doms, Stress, Mood (calcolo TQR automatico)</div>
            <div class="ph-line">⏱️ <b>Form RPE/salti:</b> seleziona sessione (AM/PM) → RPE, durata, numero salti</div>
            <div class="ph-line">📥 <b>Import scouting partita:</b> caricamento da file esterno (formato da definire) oppure inserimento manuale per fondamentale</div>
        </div>
    """, unsafe_allow_html=True)
# Out:
# 2026-07-15 19:13:33.852 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:33.855 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.516
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-15 19:13:35.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.533 Session state does not function when running a script without `streamlit run`
# 2026-07-15 19:13:35.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-15 19:13:35.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
